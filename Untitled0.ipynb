# %% [markdown]
# <a href="https://colab.research.google.com/github/rauniyarmanish563-bot/Password-generator-python/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# to find out output even factors of number
# Take a number as input from the user
num = int(input("Enter a number: "))

# Display message
print("Even factors are:")

# Loop from 1 to the given number
for i in range(1, num + 1):

    # Check if 'i' is a factor of the number
    # and also check if the factor is even
    if num % i == 0 and i % 2 == 0:

        # Print the even factor
        print(i)
# Out:
# Enter a number: 12
# Even factors are:
# 2
# 4
# 6
# 12
